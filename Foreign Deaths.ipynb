# %% [markdown]
# # Imports and Setup

# %%
import string as str
import pandas as pd
pd.set_option('display.max_columns', 1000)
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(rc={'figure.figsize':(11,8)})

# %% [markdown]
# These dataframes could be done with a for loop but it's less trouble setting it up using concat in a spreadsheet and copy-pasting it.

# %%
afghanistan = pd.read_csv('data/afghanistan.csv')
algeria = pd.read_csv('data/algeria.csv')
angola = pd.read_csv('data/angola.csv')
antigua = pd.read_csv('data/antigua.csv')
argentina = pd.read_csv('data/argentina.csv')
armenia = pd.read_csv('data/armenia.csv')
aruba = pd.read_csv('data/aruba.csv')
australia = pd.read_csv('data/australia.csv')
austria = pd.read_csv('data/austria.csv')
bahamas = pd.read_csv('data/bahamas.csv')
bahrain = pd.read_csv('data/bahrain.csv')
bangladesh = pd.read_csv('data/bangladesh.csv')
barbados = pd.read_csv('data/barbados.csv')
belgium = pd.read_csv('data/belgium.csv')
belize = pd.read_csv('data/belize.csv')
bermuda = pd.read_csv('data/bermuda.csv')
bolivia = pd.read_csv('data/bolivia.csv')
bosnia = pd.read_csv('data/bosnia.csv')
botswana = pd.read_csv('data/botswana.csv')
brazil = pd.read_csv('data/brazil.csv')
bulgaria = pd.read_csv('data/bulgaria.csv')
caboverde = pd.read_csv('data/caboverde.csv')
cambodia = pd.read_csv('data/cambodia.csv')
cameroon = pd.read_csv('data/cameroon.csv')
canada = pd.read_csv('data/canada.csv')
cayman = pd.read_csv('data/cayman.csv')
chad = pd.read_csv('data/chad.csv')
chile = pd.read_csv('data/chile.csv')
china = pd.read_csv('data/china.csv')
colombia = pd.read_csv('data/colombia.csv')
congo = pd.read_csv('data/congo.csv')
costarica = pd.read_csv('data/costarica.csv')
croatia = pd.read_csv('data/croatia.csv')
cuba = pd.read_csv('data/cuba.csv')
cyprus = pd.read_csv('data/cyprus.csv')
czech = pd.read_csv('data/czech.csv')
denmark = pd.read_csv('data/denmark.csv')
djibouti = pd.read_csv('data/djibouti.csv')
dominica = pd.read_csv('data/dominica.csv')
dr = pd.read_csv('data/dr.csv')
ecuador = pd.read_csv('data/ecuador.csv')
egypt = pd.read_csv('data/egypt.csv')
elsalvador = pd.read_csv('data/elsalvador.csv')
guinea = pd.read_csv('data/guinea.csv')
eritrea = pd.read_csv('data/eritrea.csv')
estonia = pd.read_csv('data/estonia.csv')
eswatini = pd.read_csv('data/eswatini.csv')
ethiopia = pd.read_csv('data/ethiopia.csv')
fsm = pd.read_csv('data/fsm.csv')
fiji = pd.read_csv('data/fiji.csv')
finland = pd.read_csv('data/finland.csv')
france = pd.read_csv('data/france.csv')
polynesia = pd.read_csv('data/polynesia.csv')
gambia = pd.read_csv('data/gambia.csv')
georgia = pd.read_csv('data/georgia.csv')
germany = pd.read_csv('data/germany.csv')
ghana = pd.read_csv('data/ghana.csv')
greece = pd.read_csv('data/greece.csv')
guatemala = pd.read_csv('data/guatemala.csv')
guyana = pd.read_csv('data/guyana.csv')
haiti = pd.read_csv('data/haiti.csv')
honduras = pd.read_csv('data/honduras.csv')
hongkong = pd.read_csv('data/hongkong.csv')
hungary = pd.read_csv('data/hungary.csv')
iceland = pd.read_csv('data/iceland.csv')
india = pd.read_csv('data/india.csv')
indonesia = pd.read_csv('data/indonesia.csv')
iran = pd.read_csv('data/iran.csv')
iraq = pd.read_csv('data/iraq.csv')
ireland = pd.read_csv('data/ireland.csv')
israel = pd.read_csv('data/israel.csv')
italy = pd.read_csv('data/italy.csv')
jamaica = pd.read_csv('data/jamaica.csv')
japan = pd.read_csv('data/japan.csv')
jordan = pd.read_csv('data/jordan.csv')
kazakhstan = pd.read_csv('data/kazakhstan.csv')
kenya = pd.read_csv('data/kenya.csv')
korea = pd.read_csv('data/korea.csv')
kuwait = pd.read_csv('data/kuwait.csv')
kyrgyz = pd.read_csv('data/kyrgyz.csv')
laos = pd.read_csv('data/laos.csv')
latvia = pd.read_csv('data/latvia.csv')
lebanon = pd.read_csv('data/lebanon.csv')
liberia = pd.read_csv('data/liberia.csv')
lithuania = pd.read_csv('data/lithuania.csv')
macedonia = pd.read_csv('data/macedonia.csv')
malawi = pd.read_csv('data/malawi.csv')
malaysia = pd.read_csv('data/malaysia.csv')
maldives = pd.read_csv('data/maldives.csv')
mali = pd.read_csv('data/mali.csv')
mexico = pd.read_csv('data/mexico.csv')
moldova = pd.read_csv('data/moldova.csv')
morocco = pd.read_csv('data/morocco.csv')
mozambique = pd.read_csv('data/mozambique.csv')
namibia = pd.read_csv('data/namibia.csv')
nepal = pd.read_csv('data/nepal.csv')
netherlands = pd.read_csv('data/netherlands.csv')
newzealand = pd.read_csv('data/newzealand.csv')
nicaragua = pd.read_csv('data/nicaragua.csv')
nigeria = pd.read_csv('data/nigeria.csv')
norway = pd.read_csv('data/norway.csv')
oman = pd.read_csv('data/oman.csv')
pakistan = pd.read_csv('data/pakistan.csv')
palau = pd.read_csv('data/palau.csv')
panama = pd.read_csv('data/panama.csv')
png = pd.read_csv('data/png.csv')
paraguay = pd.read_csv('data/paraguay.csv')
peru = pd.read_csv('data/peru.csv')
philippines = pd.read_csv('data/philippines.csv')
poland = pd.read_csv('data/poland.csv')
portugal = pd.read_csv('data/portugal.csv')
qatar = pd.read_csv('data/qatar.csv')
romania = pd.read_csv('data/romania.csv')
russia = pd.read_csv('data/russia.csv')
saudiarabia = pd.read_csv('data/saudiarabia.csv')
senegal = pd.read_csv('data/senegal.csv')
serbia = pd.read_csv('data/serbia.csv')
seychelles = pd.read_csv('data/seychelles.csv')
sierraleone = pd.read_csv('data/sierraleone.csv')
singapore = pd.read_csv('data/singapore.csv')
slovakia = pd.read_csv('data/slovakia.csv')
slovenia = pd.read_csv('data/slovenia.csv')
southafrica = pd.read_csv('data/southafrica.csv')
spain = pd.read_csv('data/spain.csv')
srilanka = pd.read_csv('data/srilanka.csv')
sudan = pd.read_csv('data/sudan.csv')
suriname = pd.read_csv('data/suriname.csv')
sweden = pd.read_csv('data/sweden.csv')
switzerland = pd.read_csv('data/switzerland.csv')
syria = pd.read_csv('data/syria.csv')
taiwan = pd.read_csv('data/taiwan.csv')
tanzania = pd.read_csv('data/tanzania.csv')
thailand = pd.read_csv('data/thailand.csv')
togo = pd.read_csv('data/togo.csv')
tt = pd.read_csv('data/tt.csv')
tandt = pd.read_csv('data/tAndt.csv')
tampt = pd.read_csv('data/tampt.csv')
tunisia = pd.read_csv('data/tunisia.csv')
turkey = pd.read_csv('data/turkey.csv')
tc = pd.read_csv('data/tc.csv')
tampc = pd.read_csv('data/tampc.csv')
uganda = pd.read_csv('data/uganda.csv')
ukraine = pd.read_csv('data/ukraine.csv')
uae = pd.read_csv('data/uae.csv')
uk = pd.read_csv('data/uk.csv')
uruguay = pd.read_csv('data/uruguay.csv')
uzbekistan = pd.read_csv('data/uzbekistan.csv')
venezuela = pd.read_csv('data/venezuela.csv')
vietnam = pd.read_csv('data/vietnam.csv')
yemen = pd.read_csv('data/yemen.csv')
zambia = pd.read_csv('data/zambia.csv')
zimbabwe = pd.read_csv('data/zimbabwe.csv')

# %%
afghanistan['Country'] = 'Afghanistan'
algeria['Country'] = 'Algeria'
angola['Country'] = 'Angola'
antigua['Country'] = 'Antigua'
argentina['Country'] = 'Argentina'
armenia['Country'] = 'Armenia'
aruba['Country'] = 'Aruba'
australia['Country'] = 'Australia'
austria['Country'] = 'Austria'
bahamas['Country'] = 'Bahamas'
bahrain['Country'] = 'Bahrain'
bangladesh['Country'] = 'Bangladesh'
barbados['Country'] = 'Barbados'
belgium['Country'] = 'Belgium'
belize['Country'] = 'Belize'
bermuda['Country'] = 'Bermuda'
bolivia['Country'] = 'Bolivia'
bosnia['Country'] = 'Bosnia'
botswana['Country'] = 'Botswana'
brazil['Country'] = 'Brazil'
bulgaria['Country'] = 'Bulgaria'
caboverde['Country'] = 'Caboverde'
cambodia['Country'] = 'Cambodia'
cameroon['Country'] = 'Cameroon'
canada['Country'] = 'Canada'
cayman['Country'] = 'Cayman'
chad['Country'] = 'Chad'
chile['Country'] = 'Chile'
china['Country'] = 'China'
colombia['Country'] = 'Colombia'
congo['Country'] = 'Congo'
costarica['Country'] = 'Costarica'
croatia['Country'] = 'Croatia'
cuba['Country'] = 'Cuba'
cyprus['Country'] = 'Cyprus'
czech['Country'] = 'Czech'
denmark['Country'] = 'Denmark'
djibouti['Country'] = 'Djibouti'
dominica['Country'] = 'Dominica'
dr['Country'] = 'Dominican Republic'
ecuador['Country'] = 'Ecuador'
egypt['Country'] = 'Egypt'
elsalvador['Country'] = 'Elsalvador'
guinea['Country'] = 'Guinea'
eritrea['Country'] = 'Eritrea'
estonia['Country'] = 'Estonia'
eswatini['Country'] = 'Eswatini'
ethiopia['Country'] = 'Ethiopia'
fsm['Country'] = 'Federated States of Micronesia'
fiji['Country'] = 'Fiji'
finland['Country'] = 'Finland'
france['Country'] = 'France'
polynesia['Country'] = 'Polynesia'
gambia['Country'] = 'Gambia'
georgia['Country'] = 'Georgia'
germany['Country'] = 'Germany'
ghana['Country'] = 'Ghana'
greece['Country'] = 'Greece'
guatemala['Country'] = 'Guatemala'
guyana['Country'] = 'Guyana'
haiti['Country'] = 'Haiti'
honduras['Country'] = 'Honduras'
hongkong['Country'] = 'Hongkong'
hungary['Country'] = 'Hungary'
iceland['Country'] = 'Iceland'
india['Country'] = 'India'
indonesia['Country'] = 'Indonesia'
iran['Country'] = 'Iran'
iraq['Country'] = 'Iraq'
ireland['Country'] = 'Ireland'
israel['Country'] = 'Israel'
italy['Country'] = 'Italy'
jamaica['Country'] = 'Jamaica'
japan['Country'] = 'Japan'
jordan['Country'] = 'Jordan'
kazakhstan['Country'] = 'Kazakhstan'
kenya['Country'] = 'Kenya'
korea['Country'] = 'Korea'
kuwait['Country'] = 'Kuwait'
kyrgyz['Country'] = 'Kyrgyz'
laos['Country'] = 'Laos'
latvia['Country'] = 'Latvia'
lebanon['Country'] = 'Lebanon'
liberia['Country'] = 'Liberia'
lithuania['Country'] = 'Lithuania'
macedonia['Country'] = 'Macedonia'
malawi['Country'] = 'Malawi'
malaysia['Country'] = 'Malaysia'
maldives['Country'] = 'Maldives'
mali['Country'] = 'Mali'
mexico['Country'] = 'Mexico'
moldova['Country'] = 'Moldova'
morocco['Country'] = 'Morocco'
mozambique['Country'] = 'Mozambique'
namibia['Country'] = 'Namibia'
nepal['Country'] = 'Nepal'
netherlands['Country'] = 'Netherlands'
newzealand['Country'] = 'New Zealand'
nicaragua['Country'] = 'Nicaragua'
nigeria['Country'] = 'Nigeria'
norway['Country'] = 'Norway'
oman['Country'] = 'Oman'
pakistan['Country'] = 'Pakistan'
palau['Country'] = 'Palau'
panama['Country'] = 'Panama'
png['Country'] = 'Papua New Guinea'
paraguay['Country'] = 'Paraguay'
peru['Country'] = 'Peru'
philippines['Country'] = 'Philippines'
poland['Country'] = 'Poland'
portugal['Country'] = 'Portugal'
qatar['Country'] = 'Qatar'
romania['Country'] = 'Romania'
russia['Country'] = 'Russia'
saudiarabia['Country'] = 'Saudi Arabia'
senegal['Country'] = 'Senegal'
serbia['Country'] = 'Serbia'
seychelles['Country'] = 'Seychelles'
sierraleone['Country'] = 'Sierra Leone'
singapore['Country'] = 'Singapore'
slovakia['Country'] = 'Slovakia'
slovenia['Country'] = 'Slovenia'
southafrica['Country'] = 'South Africa'
spain['Country'] = 'Spain'
srilanka['Country'] = 'Sri Lanka'
sudan['Country'] = 'Sudan'
suriname['Country'] = 'Suriname'
sweden['Country'] = 'Sweden'
switzerland['Country'] = 'Switzerland'
syria['Country'] = 'Syria'
taiwan['Country'] = 'Taiwan'
tanzania['Country'] = 'Tanzania'
thailand['Country'] = 'Thailand'
togo['Country'] = 'Togo'
tt['Country'] = 'Trinidad and Tobago'
tandt['Country'] = 'Trinidad and Tobago'
tampt['Country'] = 'Trinidad and Tobago'
tunisia['Country'] = 'Tunisia'
turkey['Country'] = 'Turkey'
tc['Country'] = 'Turks and Caicos'
tampc['Country'] = 'Turks and Caicos'
uganda['Country'] = 'Uganda'
ukraine['Country'] = 'Ukraine'
uae['Country'] = 'UAE'
uk['Country'] = 'UK'
uruguay['Country'] = 'Uruguay'
uzbekistan['Country'] = 'Uzbekistan'
venezuela['Country'] = 'Venezuela'
vietnam['Country'] = 'Vietnam'
yemen['Country'] = 'Yemen'
zambia['Country'] = 'Zambia'
zimbabwe['Country'] = 'Zimbabwe'

# %%
deaths = pd.DataFrame()

# %%
deaths = deaths.append(afghanistan)
deaths = deaths.append(algeria)
deaths = deaths.append(angola)
deaths = deaths.append(antigua)
deaths = deaths.append(argentina)
deaths = deaths.append(armenia)
deaths = deaths.append(aruba)
deaths = deaths.append(australia)
deaths = deaths.append(austria)
deaths = deaths.append(bahamas)
deaths = deaths.append(bahrain)
deaths = deaths.append(bangladesh)
deaths = deaths.append(barbados)
deaths = deaths.append(belgium)
deaths = deaths.append(belize)
deaths = deaths.append(bermuda)
deaths = deaths.append(bolivia)
deaths = deaths.append(bosnia)
deaths = deaths.append(botswana)
deaths = deaths.append(brazil)
deaths = deaths.append(bulgaria)
deaths = deaths.append(caboverde)
deaths = deaths.append(cambodia)
deaths = deaths.append(cameroon)
deaths = deaths.append(canada)
deaths = deaths.append(cayman)
deaths = deaths.append(chad)
deaths = deaths.append(chile)
deaths = deaths.append(china)
deaths = deaths.append(colombia)
deaths = deaths.append(congo)
deaths = deaths.append(costarica)
deaths = deaths.append(croatia)
deaths = deaths.append(cuba)
deaths = deaths.append(cyprus)
deaths = deaths.append(czech)
deaths = deaths.append(denmark)
deaths = deaths.append(djibouti)
deaths = deaths.append(dominica)
deaths = deaths.append(dr)
deaths = deaths.append(ecuador)
deaths = deaths.append(egypt)
deaths = deaths.append(elsalvador)
deaths = deaths.append(guinea)
deaths = deaths.append(eritrea)
deaths = deaths.append(estonia)
deaths = deaths.append(eswatini)
deaths = deaths.append(ethiopia)
deaths = deaths.append(fsm)
deaths = deaths.append(fiji)
deaths = deaths.append(finland)
deaths = deaths.append(france)
deaths = deaths.append(polynesia)
deaths = deaths.append(gambia)
deaths = deaths.append(georgia)
deaths = deaths.append(germany)
deaths = deaths.append(ghana)
deaths = deaths.append(greece)
deaths = deaths.append(guatemala)
deaths = deaths.append(guyana)
deaths = deaths.append(haiti)
deaths = deaths.append(honduras)
deaths = deaths.append(hongkong)
deaths = deaths.append(hungary)
deaths = deaths.append(iceland)
deaths = deaths.append(india)
deaths = deaths.append(indonesia)
deaths = deaths.append(iran)
deaths = deaths.append(iraq)
deaths = deaths.append(ireland)
deaths = deaths.append(israel)
deaths = deaths.append(italy)
deaths = deaths.append(jamaica)
deaths = deaths.append(japan)
deaths = deaths.append(jordan)
deaths = deaths.append(kazakhstan)
deaths = deaths.append(kenya)
deaths = deaths.append(korea)
deaths = deaths.append(kuwait)
deaths = deaths.append(kyrgyz)
deaths = deaths.append(laos)
deaths = deaths.append(latvia)
deaths = deaths.append(lebanon)
deaths = deaths.append(liberia)
deaths = deaths.append(lithuania)
deaths = deaths.append(macedonia)
deaths = deaths.append(malawi)
deaths = deaths.append(malaysia)
deaths = deaths.append(maldives)
deaths = deaths.append(mali)
deaths = deaths.append(mexico)
deaths = deaths.append(moldova)
deaths = deaths.append(morocco)
deaths = deaths.append(mozambique)
deaths = deaths.append(namibia)
deaths = deaths.append(nepal)
deaths = deaths.append(netherlands)
deaths = deaths.append(newzealand)
deaths = deaths.append(nicaragua)
deaths = deaths.append(nigeria)
deaths = deaths.append(norway)
deaths = deaths.append(oman)
deaths = deaths.append(pakistan)
deaths = deaths.append(palau)
deaths = deaths.append(panama)
deaths = deaths.append(png)
deaths = deaths.append(paraguay)
deaths = deaths.append(peru)
deaths = deaths.append(philippines)
deaths = deaths.append(poland)
deaths = deaths.append(portugal)
deaths = deaths.append(qatar)
deaths = deaths.append(romania)
deaths = deaths.append(russia)
deaths = deaths.append(saudiarabia)
deaths = deaths.append(senegal)
deaths = deaths.append(serbia)
deaths = deaths.append(seychelles)
deaths = deaths.append(sierraleone)
deaths = deaths.append(singapore)
deaths = deaths.append(slovakia)
deaths = deaths.append(slovenia)
deaths = deaths.append(southafrica)
deaths = deaths.append(spain)
deaths = deaths.append(srilanka)
deaths = deaths.append(sudan)
deaths = deaths.append(suriname)
deaths = deaths.append(sweden)
deaths = deaths.append(switzerland)
deaths = deaths.append(syria)
deaths = deaths.append(taiwan)
deaths = deaths.append(tanzania)
deaths = deaths.append(thailand)
deaths = deaths.append(togo)
deaths = deaths.append(tt)
deaths = deaths.append(tunisia)
deaths = deaths.append(turkey)
deaths = deaths.append(tc)
deaths = deaths.append(uganda)
deaths = deaths.append(ukraine)
deaths = deaths.append(uae)
deaths = deaths.append(uk)
deaths = deaths.append(uruguay)
deaths = deaths.append(uzbekistan)
deaths = deaths.append(venezuela)
deaths = deaths.append(vietnam)
deaths = deaths.append(yemen)
deaths = deaths.append(zambia)
deaths = deaths.append(zimbabwe)

# %%
deaths.reset_index(inplace=True)

# %%
deaths.head()
# Out:
#    index        Date                  City    Cause of Death      Country
# 0      0  10/25/2003  Shkin -  Afghanistan  Terrorist Action  Afghanistan
# 1      1  10/25/2003  Shkin -  Afghanistan  Terrorist Action  Afghanistan
# 2      2  08/29/2004  Kabul -  Afghanistan  Terrorist Action  Afghanistan
# 3      3  08/29/2004  Kabul -  Afghanistan  Terrorist Action  Afghanistan
# 4      4  08/29/2004  Kabul -  Afghanistan  Terrorist Action  Afghanistan

# %%
deaths.drop('index', axis=1, inplace=True)

# %%
deaths.head()
# Out:
#          Date                  City    Cause of Death      Country
# 0  10/25/2003  Shkin -  Afghanistan  Terrorist Action  Afghanistan
# 1  10/25/2003  Shkin -  Afghanistan  Terrorist Action  Afghanistan
# 2  08/29/2004  Kabul -  Afghanistan  Terrorist Action  Afghanistan
# 3  08/29/2004  Kabul -  Afghanistan  Terrorist Action  Afghanistan
# 4  08/29/2004  Kabul -  Afghanistan  Terrorist Action  Afghanistan

# %% [markdown]
# ## Data Cleaning and Preliminary Analysis

# %%
deaths['Cause of Death'].unique()
# Out:
# array(['Terrorist Action', 'Air Accident', 'Veh. Accident-Auto',
#        'Suicide', 'Homicide', 'Drowning', 'Other Accident',
#        'Train Accident', 'Drowning - River', 'Veh. Accid-Auto',
#        'Drug-Related', 'Veh. Accident-Motorcycle', 'Drowning - Beach',
#        'Drowning -Ocean', 'Veh. Accident', 'Maritime Accident',
#        'Drowning-Beach', 'Disaster', 'Other Accident - Mountain Climbing',
#        'Veh. Accident-Pedestrian', 'Drowning - Ocean',
#        'Veh. Accid-Motorcy.', 'Drowning-Ocean', 'Veh. Accident-Bus',
#        'Vehicle Acid.-Auto', 'Veh. Accident-other', 'Veh. Accid-Bus',
#        'Veh. Accid-Other', 'Veh. Accid', 'Natural Disaster',
#        'Veh.Accident-Bus', 'Veh. Accident-Other', 'Drowning-River',
#        'Veh. Accid-Pedestr.', 'Drowning - Beach ', 'Drowning-Lake',
#        'Veh-Accident-Bus', 'Veh. Accident ', 'Veh. Accident - Auto',
#        'Drowning - Pool ', 'Unknown', 'Other Accident-Mountain',
# ...

# %%
deaths['Cause of Death'].replace(['Veh. Accident-Auto', 'Veh. Accid-Auto', 'Veh. Accident-Motorcycle', 'Veh. Accident', 'Veh. Accident-Pedestrian', 'Veh. Accid-Motorycy.', 'Veh. Accident-Bus', 'Vehicle Acid.-Auto', 'Veh. Accident-other', 'Veh. Accident-Bus', 'Veh. Accid-Other', 'Veh. Accid', 'Veh. Accid-Pedestr.', 'Veh-Accident-Bus', 'Veh. Accident ', 'Veh. Accident - Auto', 'Vehicle Accident - Bus', 'Vehicle Accident - Auto', 'Veh. Accident- Auto', 'Vehicle Accident - Motorcycle', 'Vehicle Accident - Other', 'Veh. Accident - Bus', 'Veh. Accident -Auto', 'Veh.Accident-Auto', 'Vehicle Accident - Pedestrian', 'Vehic. Accident-Motorcycle', 'Veh. Accid- Bus', 'Veh. Accident-Pedestr', 'Veh. Accid-bike', 'Veh. Accid - Auto', 'Veh. Accid- Pedestr', 'Veh. Accident- Bus', 'Vehic. Accident- Other', 'Veh. Accident- Pedestrian', 'Vehic. Accident-Auto', 'Veh. Accid-Bus', 'Veh.Accident-Bus', 'Veh. Accident-Other', 'Veh. Accident - Motorcycle', 'Veh. Accid-Motorcy.', 'Veh. Accid- Auto'], 'Vehicle Accident', inplace=True)

# %%
deaths['Cause of Death'].replace(['Drowning - River', 'Drowning - Beach', 'Drowning - Ocean', 'Drowning-Ocean', 'Drowning-River', 'Drowning - Beach ', 'Drowning-Lake', 'Drowning - Pool ', 'Drowning ', 'DROWNING-Ocean', 'DROWNING-SEA', 'Drowning-BEACH', 'Drowning-Bay', 'Drowning - Pool', 'Drowning- Ocean', 'Drowning-Bridge', 'Drowning-Pool', 'Drowning - Ocean ', 'Drowning-POOL', 'Drowning-OCEAN', 'DROWNING-BEACH', 'Drowning-RIVER', 'Drowning-Beach', 'Drowning -Ocean', 'Drowning-CANAL', 'Drowning- BEACH', 'Drowning-beach'], 'Drowning', inplace=True)

# %%
deaths['Cause of Death'].replace(['Vehic. Accident-Train', 'Vehicle Accident - Train', 'Veh. Accid-Train', 'Veh. Accident-Train'], 'Train Accident', inplace=True)

# %%
deaths['Cause of Death'].replace(['Drug-related', 'Drug-Related'], 'Drug Related', inplace=True)

# %%
deaths['Cause of Death'].replace(['Other Accident - Mountain Climbing', 'Other Accident-Mountain', 'other Accident', 'Other Accident ', 'Other Accident - Rafting', 'Other  Accident', 'Other Accident- Hiking', 'Other accident'], 'Other Accident', inplace=True)

# %%
deaths['Cause of Death'].replace('Natural Disaster', 'Disaster', inplace=True)

# %%
deaths['Cause of Death'].replace(['Unknown/Undetermined', 'Under Investigation', 'Undetermined/Unknown', 'Undetermined/unknown'], 'Unknown', inplace=True)

# %%
deaths['Cause of Death'].replace(['Other Accident - Fall', 'Other Accid.-Fall', 'Other Accident-Fall', 'Other Accident- fall', 'Other Accident - fall', 'Other Accident-fall'], 'Falling', inplace=True)

# %%
deaths['Cause of Death'].replace(['Homocide', 'homicide'], 'Homicide', inplace=True)

# %%
deaths['Cause of Death'].replace('Hostage-related', 'Hostage Related', inplace=True)

# %%
deaths['Cause of Death'].unique()
# Out:
# array(['Terrorist Action', 'Air Accident', 'Vehicle Accident', 'Suicide',
#        'Homicide', 'Drowning', 'Other Accident', 'Train Accident',
#        'Drug Related', 'Maritime Accident', 'Disaster', 'Unknown',
#        'Execution', 'Other', 'Falling', 'Hostage Related',
#        'Armed Conflict'], dtype=object)

# %%
deaths.describe()
# Out:
#               Date                                  City    Cause of Death  \
# count        10814                                 10811             10814
# unique        4653                                  6118                17
# top     01/12/2010  Tijuana -  Baja California -  Mexico  Vehicle Accident
# freq           118                                   124              3311
#
#        Country
# count    10814
# unique     148
# top     Mexico
# freq      3670

# %%
sns.set(rc={'figure.figsize':(11,8)})
sns.countplot(y='Cause of Death', data=deaths)

# %%
sns.set(rc={'figure.figsize':(11,25)})
sns.countplot(y='Country', data=deaths)
plt.show()

# %%
deaths.to_csv('output/deaths.csv', index=True)
